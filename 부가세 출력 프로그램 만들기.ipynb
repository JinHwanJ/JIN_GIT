# %%
# 물건 가격 5000, 부가세 10% 일때 소비자 가격]
5000 * 1.1
# Out:
# 5500.0

# %%
# 소비자 가격에서 원래 물건 가격을 구하려면 (소비자 가격)/1.1
5500 / 1.1
# Out:
# 5000.0

# %%
round(8000 / 1.1, 1)
# Out:
# 7272.7

# %%
y = lambda x : 3 *x
y(12)
# Out:
# 36

# %%
add = lambda a,b : a + b
add(123, 12423)
# Out:
# 12546

# %%
#환률 계산기
exchange = lambda won : won * 0.00086
exchange(1000000)
# Out:
# 860.0

# %%
exchange(12312154)
# Out:
# 10588.45244

# %%
def add(a, b):
    return a + b

add(12314,124252)
# Out:
# 136566

# %%
def seperate() :
    a = int(input('자연수 중 하나를 입력하시오 : '))
    if a%2 == 0 :
        print('짝수')
    else :
        print('홀수')

# %%
seperate()
# Out:
# 자연수 중 하나를 입력하시오 : 12523521424
# 짝수

# %%
def service_price():
    service = input('서비스 종류를 입력하세요, a/b/c: ')
    valueAdded = input('부가세를 포함합니까? y/n : ')
    if valueAdded == 'y':
        if service == 'a' :
            result = 23*1.1
        if service == 'b' :
            result = 40 *1.1
        if service == 'c' :
            result = 67*1.1
    if valueAdded == 'n':
        if service == 'a' :
            result = 23
        if service == 'b' :
            result = 40
        if service == 'c' :
            result = 67
    print(round(result, 1), ' 만 원입니다 ')

# %%
service_price()
# Out:
# 서비스 종류를 입력하세요, a/b/c: a
# 부가세를 포함합니까? y/n : y
# 25.3  만 원입니다

# %%
service_price()
# Out:
# 서비스 종류를 입력하세요, a/b/c: b
# 부가세를 포함합니까? y/n : y
# 44.0  만 원입니다

# %%
service_price()
# Out:
# 서비스 종류를 입력하세요, a/b/c: c
# 부가세를 포함합니까? y/n : n
# 67  만 원입니다
